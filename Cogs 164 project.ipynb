# %%
# Basic data science packages
import numpy as np
import pandas as pd
import scipy as sp

# For analyses
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.stats.multicomp import MultiComparison

# For visualization
from PIL import Image
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
# The seaborn library makes plots look nicer
sns.set(style="darkgrid", palette = 'rainbow',font_scale = 2,rc={"lines.linewidth":2.5})
sns.set_context('talk')

# Round decimals when displaying DataFrames
pd.set_option('precision', 2)

# Set matplotlib preferences
font = {'family' : 'Bitstream Vera Sans',
        'weight' : 'regular',
        'size'   : 13}

# set standard fig size
figure = {'figsize' : (10,8)}

plt.rc('font', **font)
plt.rc('figure', **figure)

# %%
df = pd.read_excel('/Users/sarahamiraslani/Desktop/cogs164data.xlsx')

# %%
filtered = df.groupby(['Condition']).mean()

avg_EXTR = filtered['Int/extr_TOTAL']
avg_PLEAS = filtered['Pleas/agree_TOTAL']
avg_CONS = filtered['Cons/Dep_TOTAL']
avg_EMOTION = filtered['Emotion_TOTAL']
avg_INT = filtered['intellect_TOTAL']

# %%
for col in df: 
    print(col)
    
df['PK'] = df['PK_1']+df['PK_4']
# Out:
# Duration (in seconds)
# RecordedDate
# PK_1
# PK_4
# student
# gender
# age
# Condition
# Q30
# Q31
# Motivation
# Engagement
# Int/extr_TOTAL
# Pleas/agree_TOTAL
# Cons/Dep_TOTAL
# Emotion_TOTAL
# intellect_TOTAL
# Q_TOTAL
# Extraversion_median split
# PK_total
# PK_median split

# %%
sns.barplot(y='Int/extr_TOTAL',x='Condition',data=df)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /Applications/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# /Applications/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.hist2d(df['Condition'].loc,df['Condition'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-bdf8d4e245dd> in <module>
# ----> 1 plt.hist2d(df['Q_TOTAL'],df['Condition'])
#
# /Applications/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in hist2d(x, y, bins, range, normed, weights, cmin, cmax, data, **kwargs)
#    2670         x, y, bins=bins, range=range, normed=normed, weights=weights,
#    2671         cmin=cmin, cmax=cmax, **({"data": data} if data is not None
# -> 2672         else {}), **kwargs)
#    2673     sci(__ret[-1])
#    2674     return __ret
#
# /Applications/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
# ...

# %%
values = [54.4,44.3,1.3]
labels = ["female","male","non-binary"]

# %%
fig1, ax1 = plt.subplots()
plt.title("What gender do you identify with?",y=1.08)

ax1.pie(values,autopct='%1.1f%%',startangle=90,pctdistance=1.1)
ax1.axis('equal') 
ax1.legend(labels, loc = "upper right")
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/matplotlib/font_manager.py:1241: UserWarning: findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
values = [55,31.5,13.5]
labels = ["No","Yes","no-response"]

# %%
fig1, ax1 = plt.subplots()
plt.title("Did the professor's accent impair your understanding?")

ax1.pie(values,autopct='%1.1f%%',startangle=90,pctdistance=1.1)
ax1.axis('equal') 
ax1.legend(labels, loc = "upper right")

# %%
values = [26.8,28.2,45]
labels = ["A great deal","A bit","no-response"]

# %%
fig1, ax1 = plt.subplots()
plt.title("How much did the professor's accent impair your understanding?")

ax1.pie(values,autopct='%1.1f%%',startangle=90,pctdistance=1.1)
ax1.axis('equal') 
ax1.legend(labels, loc = "upper right")

# %%
sns.regplot(x='Int/extr_TOTAL',y='Q_TOTAL',data=df)

plt.title("Regression of Extraversion and Test Score")
plt.xlabel("Extraversion")
plt.ylabel('Test Score')
# Out:
# Text(0, 0.5, 'Test Score')

# %%
plt.figure()

sns.barplot(x='Condition',y='Q_TOTAL',data=df)

plt.title('Facial Visibility and Test Performance');
plt.xlabel('Condition');
plt.ylabel('Test Score');

# %%
plt.figure()

sns.barplot(x='Condition',y='Int/extr_TOTAL',data=df)

plt.title('Extraversion by Condition');
plt.xlabel('Condition');
plt.ylabel('Self-Reported Extraversion');

# %%
plt.figure()

sns.barplot(x='Condition',y='PK',data=df)

plt.title('Prior Knowledge by Condition');
plt.xlabel('Condition');
plt.ylabel('Self-reported Prior Knowledge');

# %%
plt.figure()

sns.barplot(x='Condition',y='Motivation',data=df)

plt.title('Facial Visibility and Motivation to Learn');
plt.xlabel('Condition');
plt.ylabel('Test Score');

# %%
plt.figure()

sns.barplot(x='Condition',y='Engagement',data=df)

plt.title('Facial Visibility and Engagement with Lesson');
plt.xlabel('Condition');
plt.ylabel('Test Score');

# %%
for col in df: 
    print(col)
# Out:
# Duration (in seconds)
# RecordedDate
# PK_1
# PK_4
# student
# gender
# age
# Condition
# Q30
# Q31
# Motivation
# Engagement
# Int/extr_TOTAL
# Pleas/agree_TOTAL
# Cons/Dep_TOTAL
# Emotion_TOTAL
# intellect_TOTAL
# Q_TOTAL
# Extraversion_median split
# PK_total
# PK_median split
# PK

# %%
plt.figure()

sns.barplot(x='Extraversion_median split',y='Q_TOTAL',data=df)

plt.title('Extraversion and Test Score');
plt.xlabel('Extraversion Median Split');
plt.ylabel('Test Score');

# %%
plt.figure()

sns.barplot(x='PK_median split',y='Q_TOTAL',data=df)

plt.title('Prior Knowledge and Test Score');
plt.xlabel('Prior Knowledge Median Split');
plt.ylabel('Test Score');

# %%
plt.figure()

sns.barplot(x='student',y='Q_TOTAL',data=df)

plt.title('Students and Test Score');
plt.xlabel('Are you a student?');
plt.ylabel('Test Score');
